# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Web Scraping e pré-processamento
# **Web Scraping**: o ato de baixar automaticamente os dados de uma página web e extrair informações muito específicas dela. As informações extraídas podem ser armazenadas praticamente em qualquer lugar (banco de dados, arquivo, etc.). Web scraping, também conhecido como Extração de Dados da Web, é uma maneira automatizada de extrair informações/conteúdo usando bots, conhecidos como scrapers. Aqui, as informações podem ser usadas para replicar em algum outro site ou podem ser usadas para análise de dados. ([fonte](http://datascienceacademy.com.br/blog/web-scraping-e-web-crawling-sao-legais-ou-ilegais/))
#
# **Pré-processamento**: Tratamento dos dados (remoção de stop words, pontuação, tokeninação...)

# %% [markdown]
# ## Demonstração

# %% [markdown]
# ### Web-Scraping

# %% [markdown]
# Importando as Bibliotecas necessárias

# %%
import requests
from bs4 import BeautifulSoup
import json
import pickle

# %% [markdown]
# Criando um vetor para armazenar os dados (no caso, notícias)

# %%
X = []

# %% [markdown]
# Função para baixar as notícias
# - utilizaremos a biblioteca `BeautifulSoup`

# %%
def print_headlines_tec(response_text):
    soup = BeautifulSoup(response_text, 'lxml')
    headlines   = soup.find_all('div', attrs={"itemprop": "articleBody"})

    for headline in headlines:
        X.append(headline.text)

# %% [markdown]
# Essa função, visita a URL abaixo, e baixa as notícias, como a destacada a seguir...

# %% [markdown]
# ![texto alternativo](https://blogdozouza.files.wordpress.com/2020/08/webscrap.png)

# %%
# URL que iremos utilizar...
url = 'https://inshorts.com/en/read/technology'

# %% [markdown]
# Aplicando...

# %%
response = requests.get(url)
print_headlines_tec(response.text)

# %% [markdown]
# Verificando os dados importados

# %%
X
# Out:
# ["LG's New Washing machines Range with LG Steam™ Technology pre-treats tough stains before Washing by applying intense heat. Steam Wash gives hygiene by removing 99.9%* Germs and Allergens. LG Washing Machines are also equipped with ThinQ technology that helps download upto 20 additional wash programs and helps control your washing machine through Wi-Fi from anywhere and anytime.",
#  'OPPO has announced that the F17 Pro, that comes with 6 AI portrait cameras and ultra-sleek design will be launched in India on September 2. Featuring Raftaar and Hardy Sandhu, OPPO said this will be its first-ever online music launch. The smartphone is the sleekest phone of 2020, sporting 7.48mm ultra-thin design and weighs 164 grams, it added.',
#  'Five students of the Indian Institute of Technology (IIT), Bombay, have designed a web portal to help candidates appearing for NEET and JEE find transport to their test centres. EduRide is a web portal that connects candidates across the country with volunteers willing to drive or arrange a vehicle for the aspirants to their respective test centres.',
#  'American business communication platform Slack is being criticised after it gave a security researcher only $1,750 (₹1.28 lakh) for reporting a critical vulnerability that could have allowed hackers to gain access to users\' computers. According to the researcher, the exploit could\'ve allowed hackers to run a "remote code execution". Many researchers criticised Slack for paying the researcher less.',
#  "The Eiffel Tower has topped the list of the world's top 10 'most-saved' or sought after places of all time released by Google Maps. It's followed by the Louvre Museum in Paris, the Buddhist temple Kiyomizu-dera in Kyoto, the Colosseum in Rome and La Sagrada Familia in Spain. The 'Saved' tab on Google Maps lets users bookmark their favourite locations.",
#  'World\'s second-richest person Bill Gates wished his friend Warren Buffett by baking a cake that bore the latter\'s face. Gates took to Twitter to share a video showing him bake the cake and wrote, "Happy 90th birthday, Warren!" Bill Gates and Warren Buffett, the CEO of Berkshire Hathaway and the world\'s sixth-richest person, have been friends for nearly 30 years.',
#  'Jeff Bezos-led Amazon has become one of only a handful of companies certified by the US government to operate as a drone airline. The approval allows Amazon to begin its first commercial deliveries in the US under a trial program. Amazon began testing the fleet in 2013, aiming to make deliveries in 30 minutes or less.',
#  'Elon Musk, who recently unveiled a working prototype of his brain chip company Neuralink\'s device installed in a pig, said he expects people with \'Link\' chip in their heads would be able to "save and replay memories" in future. "This is obviously sounding increasingly like a \'Black Mirror\' episode. But I guess they\'re pretty good at predicting," he added.',
#  "World's second-richest person Bill Gates wrote a blog for his friend and the world's sixth-richest person, Warren Buffett, on his 90th birthday. Gates revealed he has only two phone numbers on speed dial at his office - Melinda's (his wife's) and Warren's. Gates said it's been 10,649 days since he met Warren for the first time on July 5, 1991.",
#  'The CBDT issued a circular on 30th August advising banks to immediately refund the charges collected, if any, on or after January 1, 2020, on transactions carried out using the electronic modes prescribed under section 269SU of the Income-tax Act,1961. These include Debit cards powered by RuPay, Unified Payments Interface (UPI), UPI QR code, and BHIM UPI QR code.\n',
#  'Tesla CEO Elon Musk in response to a report on COVID-19-related deaths in the US said, "People are extremely unlikely to die of COVID/SARS-CoV-2 alone." He added that COVID-19-positive people with a weak immune system and multiple pre-existing health conditions have a "significant mortality risk". Musk had previously said that mortality rate due to COVID-19 had been "overstated".',
#  'TikTok has selected a company to buy its US, New Zealand and Australian businesses and the deal could be announced tomorrow, CNBC reported. The sale price is reportedly expected to be in the range of $20 billion to $30 billion. Microsoft, in partnership with Walmart, and Oracle are the two top contenders for the purchase.',
#  'Security researchers claim to have found the "first" Mac malware that had been approved by Apple. They found a malware campaign disguised as an Adobe Flash installer that had code notarized by Apple. They informed Apple about the malware, who then prevented it from running on Macs. However, researchers said the attackers were back with new notarized payload soon after.',
#  'Google Assistant has launched a new feature which helps users donate to humanitarian and nonprofit organisations. Google said the feature can be accessed by saying “Hey Google, donate to racial justice,” to the Assistant. The feature was rolled out starting with the Center for Policing Equity, which works for police transparency, with other charities to be added soon.',
#  "Robots have started conducting quality control checks at a factory south of Japan's Toyota City amid COVID-19. Musashi Seimitsu Industry's auto-parts plant has employed robotic arms that take about two seconds to inspect a bevel gear for surface flaws. Musashi Seimitsu and Israeli startup SixAI have established 'MusashiAI', a joint venture which develops and hires out quality control robots.",
#  "Google, in collaboration with security firm White Ops' Satori Threat Intelligence & Research team, has deleted more than 5,000 apps using an ad fraud botnet codenamed TERRACOTTA on 65,000 phones. The malware got activated after users downloaded an infected app, being lured by fraudulent offers of free shoes, tickets and goodies in exchange of the download.",
#  "Google told the Delhi High Court that it doesn't have access to the Aadhaar database and doesn't require any such information for operating the Google Pay mobile app. Earlier, it had been alleged that the NPCI has granted the app access to BHIM Aadhaar platform without knowledge of the UIDAI. The allegation was made by financial economist Abhijit Mishra.",
#  'Tesla has started releasing a software update that includes a feature called \'Speed Assist Improvements\'. It wrote in its release notes that the Speed Assist would use vehicle\'s cameras to detect speed limit signs to "improve the accuracy of speed limit data on local roads". Users will be able to adjust Speed Assist settings from Speed Limit under Autopilot controls.',
#  "Thousands of stolen 'Fortnite' accounts are being sold online daily in a black market for stolen video-game accounts that generates $1 billion annually, Night Lion Security reported. An average account sells for $200-$250. Accounts that have valuable 'skins' can sell for thousands of dollars. Hacked accounts from games like Microsoft's Minecraft and Jagex's RuneScape are popular in the market too.",
#  'Apple has brought back Music Quiz, a game produced for early iPod models, in iOS 14 as a shortcut rather than a standalone app. The quiz plays songs in shuffle mode and provides five options for users to guess which song is playing. As a shortcut, the game will work only with the native music app and Apple Music.',
#  "The New Zealand stock exchange's website crashed on Monday morning following another cyberattack. However, the NZX said the trading on its platform had continued as usual through the contingency arrangements. Last week, NZX faced disruptions for four days after it was hit repeatedly by distributed denial-of-service (DDoS) attacks.",
#  'Twitter flagged a video by House Republican Whip Steve Scalise for altering footage of a conversation between activist Ady Barkan and Joe Biden. The video was labelled as “manipulated media”, and was later pulled down. “These are not my words. I have lost my ability to speak, but not my agency or my thoughts,” Barkan, who has ALS, tweeted.',
#  'China\'s new rules around tech exports could lead to the sale of TikTok\'s US operations requiring approval from China, reported Reuters, quoting Chinese trade expert Cui Fan. China revised a list of restricted technologies that require preliminary approval for export, which could include TikTok\'s. “If ByteDance plans to export technologies, it should go through licensing procedures," said Fan.',
#  'Chinese telecom player Huawei is focusing on its cloud business, which is growing at a rapid pace, reported Financial Times. The business still reportedly has access to US chips despite the sanctions White House has imposed on the company citing national security threats. China will also support the company through public cloud contracts, according to the report. ',
#  'TikTok-parent ByteDance has said that it will "strictly follow" China\'s new technology export rules. In case of TikTok\'s US operations sale, the company would follow the applicable laws of both the US and China, ByteDance General Counsel Erich Andersen said. Earlier, China revised a list of restricted technologies that require preliminary approval from the Chinese government for export.']

# %% [markdown]
# ### Pré-Processamento

# %% [markdown]
# Importando as Bibliotecas necessárias

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from nltk.stem import WordNetLemmatizer
from string import punctuation

# %% [markdown]
# Instanciando `Stopword` e `Stemmer`

# %%
stopword = stopwords.words('english')
snowball_stemmer = SnowballStemmer('english')

# %% [markdown]
# Criação da Função para Remoção de Pontuação

# %%
def strip_punctuation(s):
        return ''.join(c for c in s if c not in punctuation)

# %% [markdown]
# #### Realizando a Limpeza...

# %%
# Cria uma variável auxiliar Xa que irá receber X
Xa = []
Xa = X

# Cria uma X vazia
X = []

# %%
for i in range(0,len(Xa)):
        text               = strip_punctuation(Xa[i]) # remove pontuacao
        text               = ''.join(c for c in text if not c.isdigit()) # remove numeros
        word_tokens        = nltk.word_tokenize(text.lower()) # processo de tokenização
        removing_stopwords = [word for word in word_tokens if word not in stopword] # remove stopwords
        stemmed_word       = [snowball_stemmer.stem(word) for word in removing_stopwords] # aplica stemmed
        X.append(stemmed_word)

# %% [markdown]
# Visualizando o tratamento dos dados

# %%
# Variável Auxiliar (lendo o primeiro registro)
Xa[0]
# Out:
# "LG's New Washing machines Range with LG Steam™ Technology pre-treats tough stains before Washing by applying intense heat. Steam Wash gives hygiene by removing 99.9%* Germs and Allergens. LG Washing Machines are also equipped with ThinQ technology that helps download upto 20 additional wash programs and helps control your washing machine through Wi-Fi from anywhere and anytime."

# %%
# Variável X tratada (lendo o primeiro registro)
X[0]
# Out:
# ['lgs',
#  'new',
#  'wash',
#  'machin',
#  'rang',
#  'lg',
#  'steam™',
#  'technolog',
#  'pretreat',
#  'tough',
#  'stain',
#  'wash',
#  'appli',
#  'intens',
#  'heat',
#  'steam',
#  'wash',
#  'give',
#  'hygien',
#  'remov',
#  'germ',
#  'allergen',
#  'lg',
#  'wash',
#  'machin',
#  'also',
#  'equip',
#  'thinq',
#  'technolog',
#  'help',
#  'download',
#  'upto',
#  'addit',
#  'wash',
#  'program',
#  'help',
#  'control',
#  'wash',
#  'machin',
#  'wifi',
#  'anywher',
#  'anytim']

# %% [markdown]
# Vendo todos os registros de X

# %%
X

# %% [markdown]
# #### Exemplo de um Classificador de Notícias
# - Luppar News-Rec ([link](https://github.com/aasouzaconsult/Cientista-de-Dados/tree/master/NLP%20-%20Classifica%C3%A7%C3%A3o%20de%20Not%C3%ADcias%20Curtas%20PTB))
#   - Explicação do algoritmo ([vídeo](https://www.youtube.com/watch?v=_ehtYMU7y3I&t=1472s))

# %% [markdown]
# ## Referências
# - (SOUZA, 2019) SOUZA, ANTONIO ALEX DE. LUPPAR NEWS-REC: UM RECOMENDADOR INTELIGENTE DE NOTÍCIAS. 2019. 95 f. Dissertação (Mestrado Acadêmico em Computação) – Universidade Estadual do Ceará, , 2019. Disponível em: <http://siduece.uece.br/siduece/trabalhoAcademicoPublico.jsf?id=93501> Acesso em: 27 de fevereiro de 2020
#
# - Alex Souza ([Blog](https://blogdozouza.wordpress.com/))
